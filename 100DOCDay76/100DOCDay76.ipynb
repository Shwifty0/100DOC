# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("apps.csv")
df.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0       8.7        0  Paid  $13.99           Teen           Social
# 1        0      33.0        0  Paid   $2.99       Everyone        Education
# 2        0       5.5        0  Paid   $1.49       Everyone  Personalization
# 3        0      19.0        0   NaN       0   Everyone 10+         Strategy
# 4        0      10.0        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# ...

# %%
df.shape, df.columns
# Out:
# ((10841, 12),
#  Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#         'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#        dtype='object'))

# %%
df.sample(5)
# Out:
#                                               App            Category  Rating  \
# 8816  Topbuzz: Breaking News, Videos & Funny GIFs  NEWS_AND_MAGAZINES     4.7
# 1099    TI-84 CE Graphing Calculator Manual TI 84              FAMILY     5.0
# 2189                                CA UIM Mobile            BUSINESS     3.2
# 9850               Masha and the Bear Child Games              FAMILY     4.1
# 1665                         Video Wallpaper Show       VIDEO_PLAYERS     NaN
#
#       Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 8816   174827      25.0  10,000,000  Free      0     Mature 17+
# 1099        1      27.0         100  Paid  $4.99       Everyone
# 2189       54       7.7       1,000  Free      0       Everyone
# 9850   288523      92.0  10,000,000  Free      0       Everyone
# 1665        0      13.0         500  Free      0       Everyone
#
#                        Genres       Last_Updated   Android_Ver
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size_MBs        10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content_Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last_Updated    10841 non-null  object
#  11  Android_Ver     10839 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1016.5+ KB

# %%
df.groupby("Genres").count()
# Out:
#                                        App  Category  Rating  Reviews  \
# Genres
# Action                                 365       365     358      365
# Action;Action & Adventure               17        17      17       17
# Adventure                               75        75      73       75
# Adventure;Action & Adventure            13        13      13       13
# Adventure;Brain Games                    1         1       1        1
# ...                                    ...       ...     ...      ...
# Video Players & Editors                173       173     158      173
# Video Players & Editors;Creativity       2         2       2        2
# Video Players & Editors;Music & Video    3         3       3        3
# Weather                                 82        82      75       82
# Word                                    29        29      28       29
#
#                                        Size_MBs  Installs  Type  Price  \
# Genres
# ...

# %%
df = df.drop(["Last_Updated", "Android_Ver"], axis=1)
df.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0       8.7        0  Paid  $13.99           Teen           Social
# 1        0      33.0        0  Paid   $2.99       Everyone        Education
# 2        0       5.5        0  Paid   $1.49       Everyone  Personalization
# 3        0      19.0        0   NaN       0   Everyone 10+         Strategy
# 4        0      10.0        0  Free       0       Everyone         Business

# %%
df["Rating"].isna().value_counts()
# Out:
# Rating
# False    9367
# True     1474
# Name: count, dtype: int64

# %%
df = df.dropna()
df.Rating.isna().value_counts()
# Out:
# Rating
# False    9367
# Name: count, dtype: int64

# %%
duplicated_rows = df[df.duplicated()]
print(duplicated_rows.shape)
duplicated_rows.head()
# Out:
# (476, 10)
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL     5.0        2
# 1133                                 MouseMingle   DATING     2.7        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL     4.4        8
# 1231                                Sway Medical  MEDICAL     5.0        3
# 1247              Chat Kids - Chat Room For Kids   DATING     4.7        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946       11.0      100  Free       0     Mature 17+  Medical
# 1133       3.9      100  Free       0     Mature 17+   Dating
# 1196       6.5      100  Paid  $12.99       Everyone  Medical
# 1231      22.0      100  Free       0       Everyone  Medical
# 1247       4.9      100  Free       0     Mature 17+   Dating

# %%
df[df.App == "Instagram"]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL     4.5  66577313       5.3  1,000,000,000  Free
# 10808  Instagram   SOCIAL     4.5  66577446       5.3  1,000,000,000  Free
# 10809  Instagram   SOCIAL     4.5  66577313       5.3  1,000,000,000  Free
# 10810  Instagram   SOCIAL     4.5  66509917       5.3  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8891 entries, 21 to 10840
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8891 non-null   object
#  1   Category        8891 non-null   object
#  2   Rating          8891 non-null   float64
#  3   Reviews         8891 non-null   int64
#  4   Size_MBs        8891 non-null   float64
#  5   Installs        8891 non-null   object
#  6   Type            8891 non-null   object
#  7   Price           8891 non-null   object
#  8   Content_Rating  8891 non-null   object
#  9   Genres          8891 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 764.1+ KB

# %%
df[df.App == "Instagram"]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL     4.5  66577313       5.3  1,000,000,000  Free
# 10808  Instagram   SOCIAL     4.5  66577446       5.3  1,000,000,000  Free
# 10810  Instagram   SOCIAL     4.5  66509917       5.3  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10810     0           Teen  Social

# %%
df = df.drop_duplicates(subset=["App", "Type", "Price"])
df[df.App == "Instagram"]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL     4.5  66577313       5.3  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %%
df.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL     5.0        4
# 28                                         Ra Ga Ba     GAME     5.0        2
# 47                                          Mu.F.O.     GAME     5.0        2
# 82                                 Brick Breaker BR     GAME     5.0        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL     5.0        1
#
#     Size_MBs Installs  Type  Price Content_Rating   Genres
# 21      25.0        1  Free      0       Everyone  Medical
# 28      20.0        1  Paid  $1.49       Everyone   Arcade
# 47      16.0        1  Paid  $0.99       Everyone   Arcade
# 82      19.0        5  Free      0       Everyone   Arcade
# 99       4.6        5  Free      0       Everyone  Medical

# %%
highest_rated_apps = df[df["Rating"] == 5.0]
highest_rated_apps.shape
# Out:
# (271, 10)

# %%
df.Size_MBs.max()
# Out:
# 100.0

# %%
df.sort_values("Reviews", ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# ...

# %%
ratings = df.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
import plotly.express as px

# %%
fig = px.pie(labels = ratings.index,
            names = ratings.index,
            values = ratings.values,
            title= "Content Rating of Applications",
            hole = 0.8)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()

# %%
df.Installs.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 8199 entries, 21 to 10835
# Series name: Installs
# Non-Null Count  Dtype
# --------------  -----
# 8199 non-null   object
# dtypes: object(1)
# memory usage: 128.1+ KB

# %%
df[["App", "Installs"]].groupby("Installs").count()
# Out:
#                 App
# Installs
# 1                 3
# 1,000           698
# 1,000,000      1417
# 1,000,000,000    20
# 10               69
# 10,000          988
# 10,000,000      933
# 100             303
# 100,000        1096
# 100,000,000     189
# 5                 9
# 5,000           425
# 5,000,000       607
# 50               56
# 50,000          457
# 50,000,000      202
# 500             199
# 500,000         504
# 500,000,000      24

# %%
df.Installs = df.Installs.astype(str).str.replace(",", "")
df.Installs = pd.to_numeric(df.Installs)
df[["App", "Installs"]].groupby("Installs").count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %%
df.Price = df.Price.astype(str).str.replace("$", "")
df.Price = pd.to_numeric(df.Price)
df.drop(df[df.Price > 250].index, inplace=True)
df.Price.value_counts()
# Out:
# Price
# 0.00     7595
# 2.99      109
# 0.99      104
# 4.99       68
# 1.99       59
#          ...
# 8.49        1
# 1.50        1
# 4.84        1
# 19.40       1
# 2.90        1
# Name: count, Length: 68, dtype: int64

# %%
df.sort_values('Price', ascending=False).head(5)
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2281  Vargo Anesthesia Mega App    MEDICAL     4.6       92      32.0
# 1407               LTC AS Legal    MEDICAL     4.0        6       1.3
# 2629           I am Rich Person  LIFESTYLE     4.2      134       1.8
# 2481    A Manual of Acupuncture    MEDICAL     3.5      214      68.0
# 2463         PTA Content Master    MEDICAL     4.2       64      41.0
#
#       Installs  Type  Price Content_Rating     Genres
# 2281      1000  Paid  79.99       Everyone    Medical
# 1407       100  Paid  39.99       Everyone    Medical
# 2629      1000  Paid  37.99       Everyone  Lifestyle
# 2481      1000  Paid  33.99       Everyone    Medical
# 2463      1000  Paid  29.99       Everyone    Medical

# %%
df["Revenue_Estimate"] = df.Price * df.Installs
df.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL     5.0        4
# 28                                         Ra Ga Ba     GAME     5.0        2
# 47                                          Mu.F.O.     GAME     5.0        2
# 82                                 Brick Breaker BR     GAME     5.0        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL     5.0        1
#
#     Size_MBs  Installs  Type  Price Content_Rating   Genres  Revenue_Estimate
# 21      25.0         1  Free   0.00       Everyone  Medical              0.00
# 28      20.0         1  Paid   1.49       Everyone   Arcade              1.49
# 47      16.0         1  Paid   0.99       Everyone   Arcade              0.99
# 82      19.0         5  Free   0.00       Everyone   Arcade              0.00
# 99       4.6         5  Free   0.00       Everyone  Medical              0.00

# %%
top_ten_highest_grossing_apps = df[["App", "Revenue_Estimate", "Category"]].sort_values("Revenue_Estimate", ascending=False)[:10]
top_ten_highest_grossing_apps[top_ten_highest_grossing_apps.Category == "GAME"]
# Out:
#                                 App  Revenue_Estimate Category
# 8825                  Hitman Sniper         9900000.0     GAME
# 7151  Grand Theft Auto: San Andreas         6990000.0     GAME
# 6594            DraStic DS Emulator         4990000.0     GAME
# 7633        Five Nights at Freddy's         2990000.0     GAME

# %%
top_ten_highest_grossing_apps.head(10)
# Out:
#                                 App  Revenue_Estimate     Category
# 9220                      Minecraft        69900000.0       FAMILY
# 8825                  Hitman Sniper         9900000.0         GAME
# 7151  Grand Theft Auto: San Andreas         6990000.0         GAME
# 7477            Facetune - For Free         5990000.0  PHOTOGRAPHY
# 7977        Sleep as Android Unlock         5990000.0    LIFESTYLE
# 6594            DraStic DS Emulator         4990000.0         GAME
# 6082                   Weather Live         2995000.0      WEATHER
# 7954                    Bloons TD 5         2990000.0       FAMILY
# 7633        Five Nights at Freddy's         2990000.0         GAME
# 6746     Card Wars - Adventure Time         2990000.0       FAMILY

# %%
top10_category = df.Category.value_counts()[:10]
top10_category
# Out:
# Category
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: count, dtype: int64

# %%
bar = px.bar(x = top10_category.index,
            y = top10_category.values)
bar.show()

# %%
category_installs = df.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)

# %%
h_bar = px.bar(x = category_installs.Installs,
                y = category_installs.index,
                orientation='h',
                title='Category Popularity')

h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()

# %%
category_apps_installs = df.groupby("Category").agg({"App":pd.Series.count , "Installs": pd.Series.sum}).sort_values("Installs",ascending=False)

# %%
scatter = px.scatter(category_apps_installs, # data
                    x='App', # column name
                    y='Installs',
                    title='Category Concentration',
                    size='App',
                    hover_name=category_apps_installs.index,
                    color='Installs')

scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                    yaxis_title="Installs",
                    yaxis=dict(type='log'))

scatter.show()

# %%
df["Genres"].value_counts()
# Out:
# Genres
# Tools                                718
# Entertainment                        467
# Education                            429
# Productivity                         301
# Personalization                      298
#                                     ...
# Adventure;Brain Games                  1
# Travel & Local;Action & Adventure      1
# Art & Design;Pretend Play              1
# Music & Audio;Music & Video            1
# Lifestyle;Pretend Play                 1
# Name: count, Length: 114, dtype: int64

# %%
# Split the strings on the semi-colon and then .stack them.
stack = df.Genres.str.split(';', expand=True).stack()
print(f'We now have a single column with shape: {stack.shape}')
num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# We now have a single column with shape: (8564,)
# Number of genres: 53

# %%
num_genres.head()
# Out:
# Tools            719
# Education        587
# Entertainment    498
# Action           304
# Productivity     301
# Name: count, dtype: int64

# %%
bar = px.bar(x = num_genres.index[:5],
            y = num_genres.values[:5],
            title= "Number of genres")
bar.show()

# %%
bar = px.bar(x = num_genres.index[:15], # index = category name
                y = num_genres.values[:15], # count
                title='Top Genres',
                hover_name=num_genres.index[:15],
                color=num_genres.values[:15],
                color_continuous_scale='Agsunset')

bar.update_layout(xaxis_title='Genre',
yaxis_title='Number of Apps',
coloraxis_showscale=False)

bar.show()

# %%
df.Type.value_counts()
# Out:
# Type
# Free    7595
# Paid     589
# Name: count, dtype: int64

# %%
df_free_vs_paid = df.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   58
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  144
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %%
g_bar = px.bar(df_free_vs_paid,
                x='Category',
                y='App',
                title='Free vs Paid Apps by Category',
                color='Type',
                barmode='group')

g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))

g_bar.show()

# %%
# Out:
#                         Installs
# Category
# ART_AND_DESIGN         114233100
# AUTO_AND_VEHICLES       53129800
# BEAUTY                  26916200
# BOOKS_AND_REFERENCE   1665791655
# BUSINESS               692018120
# COMICS                  44931100
# COMMUNICATION        11039241530
# DATING                 140912410
# EDUCATION              352852000
# ENTERTAINMENT         2113660000
# EVENTS                  15949410
# FAMILY                4437554490
# FINANCE                455249400
# FOOD_AND_DRINK         211677750
# GAME                 13858762717
# HEALTH_AND_FITNESS    1134006220
# HOUSE_AND_HOME          97082000
# LIBRARIES_AND_DEMO      52083000
# LIFESTYLE              503611120
# MAPS_AND_NAVIGATION    503267560
# MEDICAL                 39162676
# NEWS_AND_MAGAZINES    2369110650
# PARENTING               31116110
# PERSONALIZATION       1532352930
# PHOTOGRAPHY           4649143130
# PRODUCTIVITY          5788070180
# SHOPPING              1400331540
# ...

# %%
boxp = px.box(
    data_frame= df,
    x = "Type",
    y = "Installs",
    color = "Type",
    points= "all",
    notched=True,
)
boxp.update_layout(yaxis=dict(type='log'))
boxp.show()

# %%
df_paid_apps = df[df['Type'] == 'Paid']
box = px.box(df_paid_apps, 
            x='Category', 
            y='Revenue_Estimate',
            title='How Much Can Paid Apps Earn?')

box.update_layout(xaxis_title='Category',
                yaxis_title='Paid App Ballpark Revenue',
                xaxis={'categoryorder':'min ascending'},
                yaxis=dict(type='log'))


box.show()

# %%
box = px.box(df_paid_apps, 
            x='Category', 
            y='Price',
            title='Price per Category')

box.update_layout(xaxis_title='Category',
                yaxis_title='Paid App Price',
                xaxis={'categoryorder':'max descending'},
                yaxis=dict(type='log'))


box.show()
